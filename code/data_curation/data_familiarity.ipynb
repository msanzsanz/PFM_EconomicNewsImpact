# %% [markdown]
# # GETTING FAMILIAR WITH THE DATA

# %% [markdown]
# # Table of contents
# 1. [Forex Factory](#forex)
#     - [Initial exploration](#forex_explore)
#     - [Data curation & feature extraction](#next_forex)
# 2. [Forexite](#forexite)
#     - [Initial exploration](#forexite_explore)
#     - [Data curation & feature extraction](#next_forexite)

# %% [markdown]
# ## Forex Factory <a name="forex"></a>
#
#
# Data from https://www.forexfactory.com/ was gotten using our own scrapper. Thus, we need to do some sanity checks to ensure that the downloaded data corresponds to the expected one.
#
# As we have data from several years, the best approach for data curation is to create a script.
# Before that, we need to explore the data for getting familiarity with our dataset. That´s exactly the goal of this notebook.
#
#
# -----------

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import pytz

# %%
# Global variables
# Please note this are relative directories to the project, so you need to edit these variables if modifying the folder structure

data_directory = '../../data/raw/'

# %% [markdown]
# ### Initial exploration. Just for 2017, for the sake of getting familiarity with the data <a name="forex_explore"></a>

# %%
ff_2017 = pd.read_csv(data_directory + 'forexfactory_2017.csv')

# %%
ff_2017['datetime'] =  pd.to_datetime(ff_2017['datetime'])

# %%
ff_2017.head()
# Out:
#    Unnamed: 0 actual country   datetime forecast forecast_error        impact  \
# 0           0    NaN     NZD 2017-12-31      NaN            NaN  Non-Economic
# 1           1    NaN     AUD 2017-12-31      NaN            NaN  Non-Economic
# 2           2    NaN     JPY 2017-12-31      NaN            NaN  Non-Economic
# 3           3    NaN     CNY 2017-12-31      NaN            NaN  Non-Economic
# 4           4    NaN     NZD 2017-12-24      NaN            NaN  Non-Economic
#
#             new previous previous_error  week
# 0  Bank Holiday      NaN            NaN    52
# 1  Bank Holiday      NaN            NaN    52
# 2  Bank Holiday      NaN            NaN    52
# 3  Bank Holiday      NaN            NaN    52
# 4  Bank Holiday      NaN            NaN    52

# %%
ff_2017.dtypes
# Out:
# Unnamed: 0                 int64
# actual                    object
# country                   object
# datetime          datetime64[ns]
# forecast                  object
# forecast_error            object
# impact                    object
# new                       object
# previous                  object
# previous_error            object
# week                       int64
# dtype: object

# %% [markdown]
# Let´s ensure the datetime column also has the time information

# %%
str(ff_2017['datetime'][16])
# Out:
# '2017-12-25 18:30:00'

# %%
ff_2017 = ff_2017.drop(columns = ['Unnamed: 0'])

# %% [markdown]
# Please note that **"forecast_error"** is a variable that I´ve created when scrapping the website, set to NaN whenever there was no error between the published forecast and the actual value.<br/>
# Equivalently, **"previous_error"** was also created by me, set to NaN whenever there was no goverment correction on the published value for the previous release event.
#
# Let´s replace those NaN by a categorical value = 'accurate'

# %%
ff_2017['forecast_error'] = ff_2017['forecast_error'].replace(np.nan, 'accurate', regex=True)
ff_2017['previous_error'] = ff_2017['previous_error'].replace(np.nan, 'accurate', regex=True)

# %% [markdown]
# Our preliminary analysis is going to be focused on **EUR-USD only**, analysing the impact of news published by the American government, so we filter the dataframe to only get **macroeconomic news from USA** (macroeconomic news = those which have a forecast)

# %%
ff_2017_USA = ff_2017[ff_2017['country'] == 'USD'] 
ff_2017_USA = ff_2017_USA[ff_2017_USA['forecast'].notnull()]
ff_2017_USA.head()
# Out:
#    actual country            datetime forecast forecast_error  impact  \
# 27   6.4%     USD 2017-12-26 09:00:00     6.3%       accurate     Low
# 28     20     USD 2017-12-26 09:59:00       22          worse     Low
# 32  122.1     USD 2017-12-27 10:00:00    128.2          worse    High
# 33   0.2%     USD 2017-12-27 10:00:00    -0.4%         better  Medium
# 41   245K     USD 2017-12-28 08:30:00     240K          worse    High
#
#                              new previous previous_error  week
# 27   S&P/CS Composite-20 HPI y/y     6.2%       accurate    52
# 28  Richmond Manufacturing Index       30       accurate    52
# 32        CB Consumer Confidence    128.6          worse    52
# 33        Pending Home Sales m/m     3.5%       accurate    52
# 41           Unemployment Claims     245K       accurate    52

# %% [markdown]
# How many macro-economical news are published each year?

# %%
len(ff_2017_USA)
# Out:
# 872

# %% [markdown]
# How many by 'impact' rate?

# %%
ff_2017_USA_high = ff_2017_USA[ff_2017_USA['impact'] == 'High']
ff_2017_USA_medium = ff_2017_USA[ff_2017_USA['impact'] == 'Medium']
ff_2017_USA_low = ff_2017_USA[ff_2017_USA['impact'] == 'Low']

print('High: ' + str(len(ff_2017_USA_high)) + ' - Medium: ' + str(len(ff_2017_USA_medium)) + ' - Low: ' + str(len(ff_2017_USA_low)))
# Out:
# High: 296 - Medium: 243 - Low: 333

# %% [markdown]
# Our favourite news for this analysis are those with high expected impact on the market. Let´s see how many of them we have

# %%
print('number of news, high: ' + 
      str(len(ff_2017_USA_high.groupby('new').impact.count())) +
      ' - med: ' +
        str(len(ff_2017_USA_medium.groupby('new').impact.count())) +
      ' - low: ' + 
        str(len(ff_2017_USA_low.groupby('new').impact.count())))
# Out:
# number of news, high: 22 - med: 27 - low: 29

# %% [markdown]
# Hmmm, not that many... :-(

# %% [markdown]
# Let´s see how many times forex factory publishes a wrong forecast

# %%
ff_2017_USA.groupby('forecast_error').impact.count()
# Out:
# forecast_error
# accurate    301
# better      288
# worse       283
# Name: impact, dtype: int64

# %% [markdown]
# Cool, forexfactory.com publishes non-accurate forecasts around 2/3 of the times !

# %% [markdown]
# Let´s see how often HIGH news are published

# %%
ff_2017_USA_high.groupby('new').impact.count()
# Out:
# new
# ADP Non-Farm Employment Change    12
# Advance GDP q/q                    4
# Average Hourly Earnings m/m       12
# Building Permits                  12
# CB Consumer Confidence            12
# CPI m/m                           12
# Core CPI m/m                      12
# Core Durable Goods Orders m/m     12
# Core Retail Sales m/m             12
# Crude Oil Inventories             52
# Federal Funds Rate                 6
# Final GDP q/q                      4
# ISM Manufacturing PMI             12
# ISM Non-Manufacturing PMI         12
# Non-Farm Employment Change        12
# PPI m/m                           12
# Philly Fed Manufacturing Index     4
# Prelim GDP q/q                     4
# Prelim UoM Consumer Sentiment      4
# Retail Sales m/m                  12
# Unemployment Claims               50
# Unemployment Rate                 12
# Name: impact, dtype: int64

# %% [markdown]
# Mosts of them are monthly news. Let´s review one of them randomnly

# %%
ff_2017_USA[ff_2017_USA['new'] == 'ADP Non-Farm Employment Change']
# Out:
#      actual country            datetime forecast forecast_error impact  \
# 278    190K     USD 2017-12-06 08:15:00     189K       accurate   High
# 764    235K     USD 2017-11-01 07:15:00     202K         better   High
# 1111   135K     USD 2017-10-04 07:15:00     131K       accurate   High
# 1547   237K     USD 2017-08-30 07:15:00     185K         better   High
# 1884   178K     USD 2017-08-02 07:15:00     187K          worse   High
# 2215   158K     USD 2017-07-06 07:15:00     184K          worse   High
# 2672   253K     USD 2017-06-01 07:15:00     181K         better   High
# 2998   177K     USD 2017-05-03 07:15:00     178K       accurate   High
# 3368   263K     USD 2017-04-05 07:15:00     184K         better   High
# 3711   298K     USD 2017-03-08 08:15:00     184K         better   High
# 4190   246K     USD 2017-02-01 08:15:00     165K         better   High
# 4539   153K     USD 2017-01-05 08:15:00     171K          worse   High
#
#                                  new previous previous_error  week
# 278   ADP Non-Farm Employment Change     235K       accurate    49
# 764   ADP Non-Farm Employment Change     110K          worse    44
# 1111  ADP Non-Farm Employment Change     228K          worse    40
# 1547  ADP Non-Farm Employment Change     201K         better    35
# 1884  ADP Non-Farm Employment Change     191K         better    31
# 2215  ADP Non-Farm Employment Change     230K          worse    27
# 2672  ADP Non-Farm Employment Change     174K       accurate    22
# 2998  ADP Non-Farm Employment Change     255K          worse    18
# 3368  ADP Non-Farm Employment Change     245K          worse    14
# 3711  ADP Non-Farm Employment Change     261K         better    10
# 4190  ADP Non-Farm Employment Change     151K       accurate     5
# 4539  ADP Non-Farm Employment Change     215K       accurate     1

# %% [markdown]
# **Interesting...**
# Forexfactory provided its data in US/Eastern with with DST = off (as I ran the scrapper during winter time). <br/>
# This means that we need to manually add an extra hour whenever DST = on in US/Eastern. That´s exactly what forexfactory does.
#
# Extra work to be done... After some time-consuming search on google, it´s easier than originaly thought.

# %%
def add_dts_flag(df):

    # Create a list of start and end dates for US in each year, in UTC time
    dst_changes_utc = pytz.timezone('US/Eastern')._utc_transition_times[1:]

    # Convert to local times from UTC times and then remove timezone information
    dst_changes = [pd.Timestamp(i).tz_localize('UTC').tz_convert('US/Eastern').tz_localize(None) for i in dst_changes_utc]

    flag_list = []
    for index, row in df['datetime'].iteritems():
        # Isolate the start and end dates for DST in each year
        dst_dates_in_year = [date for date in dst_changes if date.year == row.year]
        spring = dst_dates_in_year[0]
        fall = dst_dates_in_year[1]
        if (row >= spring) & (row < fall):
            flag = 1
        else:
            flag = 0
        flag_list.append(flag)
    
    return flag_list

# %%
ff_2017_USA['dst_flag'] = add_dts_flag(ff_2017_USA)
ff_2017_USA[ff_2017_USA['new'] == 'ADP Non-Farm Employment Change']
# Out:
#      actual country            datetime forecast forecast_error impact  \
# 278    190K     USD 2017-12-06 08:15:00     189K       accurate   High
# 764    235K     USD 2017-11-01 07:15:00     202K         better   High
# 1111   135K     USD 2017-10-04 07:15:00     131K       accurate   High
# 1547   237K     USD 2017-08-30 07:15:00     185K         better   High
# 1884   178K     USD 2017-08-02 07:15:00     187K          worse   High
# 2215   158K     USD 2017-07-06 07:15:00     184K          worse   High
# 2672   253K     USD 2017-06-01 07:15:00     181K         better   High
# 2998   177K     USD 2017-05-03 07:15:00     178K       accurate   High
# 3368   263K     USD 2017-04-05 07:15:00     184K         better   High
# 3711   298K     USD 2017-03-08 08:15:00     184K         better   High
# 4190   246K     USD 2017-02-01 08:15:00     165K         better   High
# 4539   153K     USD 2017-01-05 08:15:00     171K          worse   High
#
#                                  new previous previous_error  week  dst_flag
# 278   ADP Non-Farm Employment Change     235K       accurate    49         0
# 764   ADP Non-Farm Employment Change     110K          worse    44         1
# 1111  ADP Non-Farm Employment Change     228K          worse    40         1
# 1547  ADP Non-Farm Employment Change     201K         better    35         1
# 1884  ADP Non-Farm Employment Change     191K         better    31         1
# 2215  ADP Non-Farm Employment Change     230K          worse    27         1
# 2672  ADP Non-Farm Employment Change     174K       accurate    22         1
# 2998  ADP Non-Farm Employment Change     255K          worse    18         1
# 3368  ADP Non-Farm Employment Change     245K          worse    14         1
# 3711  ADP Non-Farm Employment Change     261K         better    10         0
# 4190  ADP Non-Farm Employment Change     151K       accurate     5         0
# 4539  ADP Non-Farm Employment Change     215K       accurate     1         0

# %% [markdown]
# Cool, it works pretty well. Let´s apply it to the dataframe.

# %%
def apply_dts_flag(row):
    return row['datetime'] + pd.DateOffset(hours=row['dst_flag'])

# %%
ff_2017_USA['datetime'] = ff_2017_USA.apply(apply_dts_flag, axis=1)

# %%
ff_2017_USA[ff_2017_USA['new'] == 'ADP Non-Farm Employment Change']
# Out:
#      actual country            datetime forecast forecast_error impact  \
# 278    190K     USD 2017-12-06 08:15:00     189K       accurate   High
# 764    235K     USD 2017-11-01 08:15:00     202K         better   High
# 1111   135K     USD 2017-10-04 08:15:00     131K       accurate   High
# 1547   237K     USD 2017-08-30 08:15:00     185K         better   High
# 1884   178K     USD 2017-08-02 08:15:00     187K          worse   High
# 2215   158K     USD 2017-07-06 08:15:00     184K          worse   High
# 2672   253K     USD 2017-06-01 08:15:00     181K         better   High
# 2998   177K     USD 2017-05-03 08:15:00     178K       accurate   High
# 3368   263K     USD 2017-04-05 08:15:00     184K         better   High
# 3711   298K     USD 2017-03-08 08:15:00     184K         better   High
# 4190   246K     USD 2017-02-01 08:15:00     165K         better   High
# 4539   153K     USD 2017-01-05 08:15:00     171K          worse   High
#
#                                  new previous previous_error  week  dst_flag
# 278   ADP Non-Farm Employment Change     235K       accurate    49         0
# 764   ADP Non-Farm Employment Change     110K          worse    44         1
# 1111  ADP Non-Farm Employment Change     228K          worse    40         1
# 1547  ADP Non-Farm Employment Change     201K         better    35         1
# 1884  ADP Non-Farm Employment Change     191K         better    31         1
# 2215  ADP Non-Farm Employment Change     230K          worse    27         1
# 2672  ADP Non-Farm Employment Change     174K       accurate    22         1
# 2998  ADP Non-Farm Employment Change     255K          worse    18         1
# 3368  ADP Non-Farm Employment Change     245K          worse    14         1
# 3711  ADP Non-Farm Employment Change     261K         better    10         0
# 4190  ADP Non-Farm Employment Change     151K       accurate     5         0
# 4539  ADP Non-Farm Employment Change     215K       accurate     1         0

# %% [markdown]
# As forexite was downloaded in GMT, no DTS, we would need to do the conversion before merging both dataframes

# %%
ff_2017_USA['datetime_gmt'] = ff_2017_USA['datetime'].dt.tz_localize('US/Eastern').dt.tz_convert('GMT')
ff_2017_USA[ff_2017_USA['new'] == 'ADP Non-Farm Employment Change']
# Out:
#      actual country            datetime forecast forecast_error impact  \
# 278    190K     USD 2017-12-06 08:15:00     189K       accurate   High
# 764    235K     USD 2017-11-01 08:15:00     202K         better   High
# 1111   135K     USD 2017-10-04 08:15:00     131K       accurate   High
# 1547   237K     USD 2017-08-30 08:15:00     185K         better   High
# 1884   178K     USD 2017-08-02 08:15:00     187K          worse   High
# 2215   158K     USD 2017-07-06 08:15:00     184K          worse   High
# 2672   253K     USD 2017-06-01 08:15:00     181K         better   High
# 2998   177K     USD 2017-05-03 08:15:00     178K       accurate   High
# 3368   263K     USD 2017-04-05 08:15:00     184K         better   High
# 3711   298K     USD 2017-03-08 08:15:00     184K         better   High
# 4190   246K     USD 2017-02-01 08:15:00     165K         better   High
# 4539   153K     USD 2017-01-05 08:15:00     171K          worse   High
#
#                                  new previous previous_error  week  dst_flag  \
# 278   ADP Non-Farm Employment Change     235K       accurate    49         0
# 764   ADP Non-Farm Employment Change     110K          worse    44         1
# 1111  ADP Non-Farm Employment Change     228K          worse    40         1
# 1547  ADP Non-Farm Employment Change     201K         better    35         1
# 1884  ADP Non-Farm Employment Change     191K         better    31         1
# 2215  ADP Non-Farm Employment Change     230K          worse    27         1
# 2672  ADP Non-Farm Employment Change     174K       accurate    22         1
# 2998  ADP Non-Farm Employment Change     255K          worse    18         1
# 3368  ADP Non-Farm Employment Change     245K          worse    14         1
# 3711  ADP Non-Farm Employment Change     261K         better    10         0
# 4190  ADP Non-Farm Employment Change     151K       accurate     5         0
# 4539  ADP Non-Farm Employment Change     215K       accurate     1         0
#
#                   datetime_gmt
# 278  2017-12-06 13:15:00+00:00
# 764  2017-11-01 12:15:00+00:00
# 1111 2017-10-04 12:15:00+00:00
# 1547 2017-08-30 12:15:00+00:00
# 1884 2017-08-02 12:15:00+00:00
# 2215 2017-07-06 12:15:00+00:00
# 2672 2017-06-01 12:15:00+00:00
# 2998 2017-05-03 12:15:00+00:00
# 3368 2017-04-05 12:15:00+00:00
# 3711 2017-03-08 13:15:00+00:00
# 4190 2017-02-01 13:15:00+00:00
# 4539 2017-01-05 13:15:00+00:00

# %% [markdown]
# -----------
# On a different topic, we would also need to know which units are used per each macroeconomic new, so that we can compute the error rate between forecast and reality.

# %%
list(set(ff_2017_USA.groupby('new').first().forecast))
# Out:
# ['58.4',
#  '97.1',
#  '-135.2B',
#  '-67.7B',
#  '104.6',
#  '99.0',
#  '198K',
#  '62.2',
#  '0.7%',
#  '57.6B',
#  '-116B',
#  '0.5%',
#  '2.1%',
#  '3.3%',
#  '-3.9M',
#  '-0.4%',
#  '18.8',
#  '54.8',
#  '22',
#  '1.27M',
#  '4.1%',
#  '2.6%',
#  '0.6%',
#  '0.4%',
#  '17.5M',
#  '6.3%',
#  '2.5%',
#  '6.03M',
#  '54.0',
#  '-0.1%',
#  '-115B',
#  '55.4',
#  '5.53M',
#  '1.25M',
#  '-0.3%',
#  '189K',
#  '2.2%',
#  '59.2',
#  '240K',
#  '654K',
#  '1.7%',
#  '17.4B',
#  '0.2%',
#  '-46.2B',
#  '0.3%',
#  '70',
#  '77.2%',
#  '54.6',
#  '67.0',
#  '21.5',
#  '<1.50%',
#  '53.8',
#  '0.1%',
#  '128.2']

# %% [markdown]
# OK, again this is not nice... Extra processing will need to be done to compute error_ratio

# %% [markdown]
# ---
#
# ## Next steps on Forex Factory <a name="next_forex"></a>
#
#
# ### Sanity checks:
#
#  - No missing weeks. Each year should have 52 weeks.
#
# ### Data selection:
#
#  - Filter just macro-economic news.
#  - Filter news just on the currency of interest.
#
# ### Feature Engineer:
#
#  - Replace NaN in "forecast_error" and "previous_error" fields by "accurate".
#  - Manually add +1h to forexfactory data to account for DTS (date time savings).
#  - Set all timestamps to match the trading pair values got from Forexite, i.e. GMT without DTS. Otherwise we won´t compare apples with apples !
#  - Compute percentage of error between the forecasted and actual values, taking into account the different units handled (int, float, %, Millions = 'M', Thousands = 'K').
#  - Add year, quarter, month, day of week as caegorical variables.
#
#
# <br/>
#
# ----

# %% [markdown]
# ## Forexite <a name="forexite"></a>

# %% [markdown]
# ### Initial exploration. Just EUR-USD, for the sake of getting familiarity with the data <a name="forexite_explore"></a>

# %% [markdown]
# Currency data from https://forextester.com/data/datasources is already provided as csv files, one per each currency pair.

# %%
eurusd = pd.read_csv(data_directory + 'EURUSD.zip', compression='zip', header=0, sep=',')

# %%
eurusd.head()
# Out:
#                   Gmt time     Open     High      Low    Close  Volume
# 0  01.01.2007 00:00:00.000  1.31908  1.31961  1.31896  1.31947  5268.6
# 1  01.01.2007 00:05:00.000  1.31942  1.31963  1.31935  1.31945  4019.1
# 2  01.01.2007 00:10:00.000  1.31959  1.31964  1.31928  1.31953  3784.6
# 3  01.01.2007 00:15:00.000  1.31942  1.31961  1.31918  1.31929  3550.8
# 4  01.01.2007 00:20:00.000  1.31919  1.31934  1.31902  1.31923  4096.8

# %%
eurusd.dtypes
# Out:
# Gmt time     object
# Open        float64
# High        float64
# Low         float64
# Close       float64
# Volume      float64
# dtype: object

# %% [markdown]
# The data is listed by minute. We won´t be interested is such degree of granularity. For our study, we will need to group this data into broader chunks

# %%
eurusd.describe()
# Out:
#                Open          High           Low         Close        Volume
# count  1.245888e+06  1.245888e+06  1.245888e+06  1.245888e+06  1.245888e+06
# mean   1.287445e+00  1.287671e+00  1.287212e+00  1.287445e+00  8.826395e+02
# std    1.296695e-01  1.297179e-01  1.296122e-01  1.296695e-01  1.749533e+03
# min    1.034520e+00  1.035840e+00  1.034030e+00  1.034530e+00  0.000000e+00
# 25%    1.170860e+00  1.171070e+00  1.170660e+00  1.170860e+00  0.000000e+00
# 50%    1.306790e+00  1.306950e+00  1.306700e+00  1.306790e+00  3.803200e+02
# 75%    1.371960e+00  1.372290e+00  1.371670e+00  1.371950e+00  1.032592e+03
# max    1.603430e+00  1.603890e+00  1.601550e+00  1.603050e+00  2.290818e+05

# %% [markdown]
# ---
#
# ## Feature engineer using Dukascopy data <a name="next_dukas"></a>
#
# Dukascopy provides the exchange rate for the major pairs of interest. We will use this data to evaluate the impact in that pair created by the releases of macroeconomic data
#
# #### Situation of the market _before_ publishing the new:
#
#  - Create a new dataframe, grouping the data per day (open, high, low, close).
#  - Add 12 new features to the news dataframe -> (open, high, low, close) for the 3 days prior to the new publication.
#
# #### Situation of the market _after_ publishing the new:
#
#  - 5,10,15,30,60,90,120-min window size (volatility (high - low), direction (up|down), close).
#
#
# ## Feature engineer <a name="feature_engineer"></a>
#
#  - Dataframe:
#       - surprise_forecast
#       - surprise_volatility
#
#
# <br/>
#
# ----

# %%
ff_2017_USA[ff_2017_USA['new'] == 'Unemployment Rate']
# Out:
#      actual country            datetime forecast forecast_error impact  \
# 332    4.1%     USD 2017-12-08 08:30:00     4.1%       accurate   High
# 816    4.1%     USD 2017-11-03 08:30:00     4.2%         better   High
# 1152   4.2%     USD 2017-10-06 08:30:00     4.4%         better   High
# 1596   4.4%     USD 2017-09-01 08:30:00     4.3%          worse   High
# 1924   4.3%     USD 2017-08-04 08:30:00     4.3%       accurate   High
# 2247   4.4%     USD 2017-07-07 08:30:00     4.3%          worse   High
# 2694   4.3%     USD 2017-06-02 08:30:00     4.4%         better   High
# 3044   4.4%     USD 2017-05-05 08:30:00     4.6%         better   High
# 3412   4.5%     USD 2017-04-07 08:30:00     4.7%         better   High
# 3756   4.7%     USD 2017-03-10 08:30:00     4.7%       accurate   High
# 4239   4.8%     USD 2017-02-03 08:30:00     4.7%          worse   High
# 4561   4.7%     USD 2017-01-06 08:30:00     4.7%       accurate   High
#
#                     new previous previous_error  week  dst_flag  \
# 332   Unemployment Rate     4.1%       accurate    49         0
# 816   Unemployment Rate     4.2%       accurate    44         1
# 1152  Unemployment Rate     4.4%       accurate    40         1
# 1596  Unemployment Rate     4.3%       accurate    35         1
# 1924  Unemployment Rate     4.4%       accurate    31         1
# 2247  Unemployment Rate     4.3%       accurate    27         1
# 2694  Unemployment Rate     4.4%       accurate    22         1
# 3044  Unemployment Rate     4.5%       accurate    18         1
# 3412  Unemployment Rate     4.7%       accurate    14         1
# 3756  Unemployment Rate     4.8%       accurate    10         0
# 4239  Unemployment Rate     4.7%       accurate     5         0
# 4561  Unemployment Rate     4.6%       accurate     1         0
#
#                   datetime_gmt                   a_5_min
# 332  2017-12-08 13:30:00+00:00 2017-12-08 13:35:00+00:00
# 816  2017-11-03 12:30:00+00:00 2017-11-03 12:35:00+00:00
# 1152 2017-10-06 12:30:00+00:00 2017-10-06 12:35:00+00:00
# 1596 2017-09-01 12:30:00+00:00 2017-09-01 12:35:00+00:00
# 1924 2017-08-04 12:30:00+00:00 2017-08-04 12:35:00+00:00
# 2247 2017-07-07 12:30:00+00:00 2017-07-07 12:35:00+00:00
# 2694 2017-06-02 12:30:00+00:00 2017-06-02 12:35:00+00:00
# 3044 2017-05-05 12:30:00+00:00 2017-05-05 12:35:00+00:00
# 3412 2017-04-07 12:30:00+00:00 2017-04-07 12:35:00+00:00
# 3756 2017-03-10 13:30:00+00:00 2017-03-10 13:35:00+00:00
# 4239 2017-02-03 13:30:00+00:00 2017-02-03 13:35:00+00:00
# 4561 2017-01-06 13:30:00+00:00 2017-01-06 13:35:00+00:00

# %%
df = pd.read_csv('../../data/curated/macroeconomic_news_2007_2018.csv')
df.head(2)
# Out:
#   actual country             datetime forecast forecast_error impact  \
# 0  12.3B     USD  2007-01-08 15:00:00     5.4B         better    Low
# 1   53.7     USD  2007-01-09 10:00:00     53.7       accurate    Low
#
#                           new previous previous_error  week      ...        \
# 0         Consumer Credit m/m    -1.3B       accurate     2      ...
# 1  IBD/TIPP Economic Optimism     53.5       accurate     2      ...
#
#   direction_60  pips_diff_60  close_90  volatility_90  direction_90  \
# 0         down           2.0     13019              5            up
# 1         down           1.0     12994              5          down
#
#   pips_diff_90  close_120  volatility_120  direction_120  pips_diff_120
# 0          1.0      13019               5           down            1.0
# 1          6.0      12993               6           down            7.0
#
# [2 rows x 48 columns]

# %%
df[(df['new'] ==  'Unemployment Rate') & (df['year'] == 2018)][['new', 'impact','datetime','datetime_gmt', 'open_released','high_released','low_released','close_released']]
# Out:
#                     new impact             datetime  \
# 8765  Unemployment Rate   High  2018-01-05 08:30:00
# 8834  Unemployment Rate   High  2018-02-02 08:30:00
# 8911  Unemployment Rate   High  2018-03-09 08:30:00
# 8981  Unemployment Rate   High  2018-04-06 08:30:00
# 9052  Unemployment Rate   High  2018-05-04 08:30:00
# 9110  Unemployment Rate   High  2018-06-01 08:30:00
# 9191  Unemployment Rate   High  2018-07-06 08:30:00
# 9259  Unemployment Rate   High  2018-08-03 08:30:00
# 9337  Unemployment Rate   High  2018-09-07 08:30:00
# 9405  Unemployment Rate   High  2018-10-05 08:30:00
#
#                    datetime_gmt  open_released  high_released  low_released  \
# 8765  2018-01-05 13:30:00+00:00        1.20492        12051.0       12046.0
# 8834  2018-02-02 13:30:00+00:00        1.24910        12497.0       12490.0
# 8911  2018-03-09 13:30:00+00:00        1.22853        12288.0       12282.0
# 8981  2018-04-06 12:30:00+00:00        1.22345        12241.0       12230.0
# 9052  2018-05-04 12:30:00+00:00        1.19674        11968.0       11959.0
# 9110  2018-06-01 12:30:00+00:00        1.16690        11673.0       11667.0
# 9191  2018-07-06 12:30:00+00:00        1.17208        11722.0       11713.0
# 9259  2018-08-03 12:30:00+00:00        1.15889        11590.0       11585.0
# 9337  2018-09-07 12:30:00+00:00        1.16113        11620.0       11611.0
# 9405  2018-10-05 12:30:00+00:00        1.15056        11509.0       11504.0
#
#       close_released
# 8765         12051.0
# 8834         12492.0
# 8911         12285.0
# 8981         12230.0
# 9052         11964.0
# 9110         11672.0
# 9191         11716.0
# 9259         11587.0
# 9337         11618.0
# 9405         11506.0

# %%
df[(df['new'] ==  'Unemployment Claims') & (df['year'] == 2017)][['new', 'impact','datetime','datetime_gmt', 'open_released','high_released','low_released','close_released']]
# Out:
#                       new  impact             datetime  \
# 7909  Unemployment Claims    High  2017-01-05 08:30:00
# 7925  Unemployment Claims    High  2017-01-12 08:30:00
# 7944  Unemployment Claims    High  2017-01-19 08:30:00
# 7953  Unemployment Claims    High  2017-01-26 08:30:00
# 7981  Unemployment Claims    High  2017-02-02 08:30:00
# 7996  Unemployment Claims    High  2017-02-09 08:30:00
# 8017  Unemployment Claims    High  2017-02-16 08:30:00
# 8024  Unemployment Claims    High  2017-02-23 08:30:00
# 8049  Unemployment Claims    High  2017-03-02 08:30:00
# 8062  Unemployment Claims    High  2017-03-09 08:30:00
# 8084  Unemployment Claims    High  2017-03-16 08:30:00
# 8096  Unemployment Claims    High  2017-03-23 08:30:00
# 8110  Unemployment Claims    High  2017-03-30 08:30:00
# 8130  Unemployment Claims    High  2017-04-06 08:30:00
# 8143  Unemployment Claims    High  2017-04-13 08:30:00
# 8161  Unemployment Claims    High  2017-04-20 08:30:00
# 8173  Unemployment Claims    High  2017-04-27 08:30:00
# 8197  Unemployment Claims    High  2017-05-04 08:30:00
# 8215  Unemployment Claims    High  2017-05-11 08:30:00
# 8232  Unemployment Claims    High  2017-05-18 08:30:00
# 8241  Unemployment Claims    High  2017-05-25 08:30:00
# 8259  Unemployment Claims    High  2017-06-01 08:30:00
# 8278  Unemployment Claims    High  2017-06-08 08:30:00
# 8292  Unemployment Claims    High  2017-06-15 08:30:00
# 8307  Unemployment Claims    High  2017-06-22 08:30:00
# 8323  Unemployment Claims    High  2017-06-29 08:30:00
# 8338  Unemployment Claims    High  2017-07-06 08:30:00
# 8353  Unemployment Claims    High  2017-07-13 08:30:00
# 8371  Unemployment Claims    High  2017-07-20 08:30:00
# 8385  Unemployment Claims    High  2017-07-27 08:30:00
# 8406  Unemployment Claims    High  2017-08-03 08:30:00
# 8424  Unemployment Claims    High  2017-08-10 08:30:00
# 8440  Unemployment Claims    High  2017-08-17 08:30:00
# 8450  Unemployment Claims    High  2017-08-24 08:30:00
# 8463  Unemployment Claims    High  2017-08-31 08:30:00
# 8483  Unemployment Claims    High  2017-09-07 08:30:00
# 8497  Unemployment Claims    High  2017-09-14 08:30:00
# 8515  Unemployment Claims    High  2017-09-21 08:30:00
# 8530  Unemployment Claims    High  2017-09-28 08:30:00
# 8549  Unemployment Claims    High  2017-10-05 08:30:00
# 8562  Unemployment Claims    High  2017-10-12 08:30:00
# 8581  Unemployment Claims    High  2017-10-19 08:30:00
# 8594  Unemployment Claims    High  2017-10-26 08:30:00
# 8617  Unemployment Claims    High  2017-11-02 08:30:00
# 8632  Unemployment Claims    High  2017-11-09 08:30:00
# 8648  Unemployment Claims    High  2017-11-16 08:30:00
# 8659  Unemployment Claims    High  2017-11-22 08:30:00
# 8676  Unemployment Claims    High  2017-11-30 08:30:00
# 8695  Unemployment Claims    High  2017-12-07 08:30:00
# 8715  Unemployment Claims  Medium  2017-12-14 08:30:00
# 8732  Unemployment Claims  Medium  2017-12-21 08:30:00
# 8747  Unemployment Claims    High  2017-12-28 08:30:00
#
#                    datetime_gmt  open_released  high_released  low_released  \
# 7909  2017-01-05 13:30:00+00:00        1.05187        10521.0       10514.0
# 7925  2017-01-12 13:30:00+00:00        1.06659        10667.0       10662.0
# 7944  2017-01-19 13:30:00+00:00        1.06693        10670.0       10667.0
# 7953  2017-01-26 13:30:00+00:00        1.06921        10695.0       10689.0
# 7981  2017-02-02 13:30:00+00:00        1.08133        10814.0       10812.0
# 7996  2017-02-09 13:30:00+00:00        1.06850        10686.0       10680.0
# 8017  2017-02-16 13:30:00+00:00        1.06483        10650.0       10648.0
# 8024  2017-02-23 13:30:00+00:00        1.05717        10575.0       10568.0
# 8049  2017-03-02 13:30:00+00:00        1.05161        10518.0       10515.0
# 8062  2017-03-09 13:30:00+00:00        1.05548        10558.0       10554.0
# 8084  2017-03-16 12:30:00+00:00        1.07195        10721.0       10717.0
# 8096  2017-03-23 12:30:00+00:00        1.07776        10779.0       10776.0
# 8110  2017-03-30 12:30:00+00:00        1.07419        10744.0       10739.0
# 8130  2017-04-06 12:30:00+00:00        1.06623        10664.0       10658.0
# 8143  2017-04-13 12:30:00+00:00        1.06270        10629.0       10627.0
# 8161  2017-04-20 12:30:00+00:00        1.07445        10747.0       10743.0
# 8173  2017-04-27 12:30:00+00:00        1.08904        10893.0       10885.0
# 8197  2017-05-04 12:30:00+00:00        1.09252        10926.0       10921.0
# 8215  2017-05-11 12:30:00+00:00        1.08510        10853.0       10849.0
# 8232  2017-05-18 12:30:00+00:00        1.11326        11137.0       11132.0
# 8241  2017-05-25 12:30:00+00:00        1.12080        11208.0       11205.0
# 8259  2017-06-01 12:30:00+00:00        1.12052        11210.0       11205.0
# 8278  2017-06-08 12:30:00+00:00        1.12288        11234.0       11228.0
# 8292  2017-06-15 12:30:00+00:00        1.11612        11166.0       11159.0
# 8307  2017-06-22 12:30:00+00:00        1.11702        11170.0       11168.0
# 8323  2017-06-29 12:30:00+00:00        1.14110        11411.0       11402.0
# 8338  2017-07-06 12:30:00+00:00        1.13898        11390.0       11387.0
# 8353  2017-07-13 12:30:00+00:00        1.14179        11418.0       11412.0
# 8371  2017-07-20 12:30:00+00:00        1.14901        11493.0       11489.0
# 8385  2017-07-27 12:30:00+00:00        1.16929        11699.0       11693.0
# 8406  2017-08-03 12:30:00+00:00        1.18624        11874.0       11862.0
# 8424  2017-08-10 12:30:00+00:00        1.17278        11732.0       11726.0
# 8440  2017-08-17 12:30:00+00:00        1.16938        11699.0       11691.0
# 8450  2017-08-24 12:30:00+00:00        1.18045        11806.0       11802.0
# 8463  2017-08-31 12:30:00+00:00        1.18316        11835.0       11831.0
# 8483  2017-09-07 12:30:00+00:00        1.19700        11974.0       11963.0
# 8497  2017-09-14 12:30:00+00:00        1.18963        11901.0       11890.0
# 8515  2017-09-21 12:30:00+00:00        1.19154        11915.0       11913.0
# 8530  2017-09-28 12:30:00+00:00        1.17817        11784.0       11778.0
# 8549  2017-10-05 12:30:00+00:00        1.17412        11742.0       11739.0
# 8562  2017-10-12 12:30:00+00:00        1.18535        11854.0       11852.0
# 8581  2017-10-19 12:30:00+00:00        1.18402        11842.0       11838.0
# 8594  2017-10-26 12:30:00+00:00        1.17472        11757.0       11747.0
# 8617  2017-11-02 12:30:00+00:00        1.16561        11659.0       11655.0
# 8632  2017-11-09 13:30:00+00:00        1.16291        11629.0       11625.0
# 8648  2017-11-16 13:30:00+00:00        1.17709        11771.0       11768.0
# 8659  2017-11-22 13:30:00+00:00        1.17434        11750.0       11742.0
# 8676  2017-11-30 13:30:00+00:00        1.18469        11851.0       11847.0
# 8695  2017-12-07 13:30:00+00:00        1.17882        11791.0       11787.0
# 8715  2017-12-14 13:30:00+00:00        1.18388        11844.0       11839.0
# 8732  2017-12-21 13:30:00+00:00        1.18612        11862.0       11856.0
# 8747  2017-12-28 13:30:00+00:00        1.19380        11943.0       11937.0
#
#       close_released
# 7909         10518.0
# 7925         10664.0
# 7944         10668.0
# 7953         10694.0
# 7981         10812.0
# 7996         10682.0
# 8017         10649.0
# 8024         10570.0
# 8049         10517.0
# 8062         10556.0
# 8084         10720.0
# 8096         10777.0
# 8110         10739.0
# 8130         10658.0
# 8143         10629.0
# 8161         10747.0
# 8173         10890.0
# 8197         10923.0
# 8215         10849.0
# 8232         11135.0
# 8241         11206.0
# 8259         11208.0
# 8278         11232.0
# 8292         11164.0
# 8307         11169.0
# 8323         11404.0
# 8338         11389.0
# 8353         11414.0
# 8371         11493.0
# 8385         11699.0
# 8406         11872.0
# 8424         11731.0
# 8440         11697.0
# 8450         11803.0
# 8463         11832.0
# 8483         11968.0
# 8497         11894.0
# 8515         11914.0
# 8530         11778.0
# 8549         11740.0
# 8562         11853.0
# 8581         11839.0
# 8594         11752.0
# 8617         11659.0
# 8632         11626.0
# 8648         11769.0
# 8659         11746.0
# 8676         11850.0
# 8695         11790.0
# 8715         11843.0
# 8732         11857.0
# 8747         11942.0

# %%
df = pd.read_csv("/Users/wola/Documents/MSS/Personales/GitRepos/PFM_EconomicNewsImpact/data/curated/macroeconomic_news_2007_2018.csv")

# %%
df_nan = df[df['new'] == 'Unemployment Rate']

# %%
df[(df['new'] ==  'Unemployment Rate') & (df['year'] == 2018)][['new', 'impact','datetime','datetime_gmt', 'open_released','high_released','low_released','close_released']]
# Out:
#                     new impact             datetime  \
# 8664  Unemployment Rate   High  2018-01-05 08:30:00
# 8727  Unemployment Rate   High  2018-02-02 08:30:00
# 8804  Unemployment Rate   High  2018-03-09 08:30:00
# 8874  Unemployment Rate   High  2018-04-06 08:30:00
# 8939  Unemployment Rate   High  2018-05-04 08:30:00
# 8997  Unemployment Rate   High  2018-06-01 08:30:00
# 9077  Unemployment Rate   High  2018-07-06 08:30:00
# 9145  Unemployment Rate   High  2018-08-03 08:30:00
# 9222  Unemployment Rate   High  2018-09-07 08:30:00
# 9290  Unemployment Rate   High  2018-10-05 08:30:00
#
#                    datetime_gmt  open_released  high_released  low_released  \
# 8664  2018-01-05 13:30:00+00:00         1.2043        12046.0       12043.0
# 8727  2018-02-02 13:30:00+00:00         1.2488        12488.0       12486.0
# 8804  2018-03-09 13:30:00+00:00         1.2284        12285.0       12283.0
# 8874  2018-04-06 12:30:00+00:00         1.2233        12239.0       12229.0
# 8939  2018-05-04 12:30:00+00:00         1.1965        11966.0       11957.0
# 8997  2018-06-01 12:30:00+00:00         1.1667        11672.0       11666.0
# 9077  2018-07-06 12:30:00+00:00         1.1716        11717.0       11713.0
# 9145  2018-08-03 12:30:00+00:00         1.1587        11587.0       11584.0
# 9222  2018-09-07 12:30:00+00:00         1.1609        11617.0       11609.0
# 9290  2018-10-05 12:30:00+00:00         1.1506        11507.0       11506.0
#
#       close_released
# 8664         12046.0
# 8727         12486.0
# 8804         12283.0
# 8874         12230.0
# 8939         11961.0
# 8997         11670.0
# 9077         11713.0
# 9145         11586.0
# 9222         11617.0
# 9290         11507.0

# %%
df_nan[['new', 'datetime_gmt','forecast','actual', 'prediction_error', 'prediction_mean', 'prediction_std', 'prediction_zscore']].head(10)
# Out:
#                     new               datetime_gmt forecast actual  \
# 7895  Unemployment Rate  2007-02-02 13:30:00+00:00     4.5%   4.6%
# 7896  Unemployment Rate  2007-03-09 13:30:00+00:00     4.6%   4.5%
# 7897  Unemployment Rate  2007-04-06 12:30:00+00:00     4.6%   4.4%
# 7898  Unemployment Rate  2007-05-04 12:30:00+00:00     4.5%   4.5%
# 7899  Unemployment Rate  2007-06-01 12:30:00+00:00     4.5%   4.5%
# 7900  Unemployment Rate  2007-07-06 12:30:00+00:00     4.5%   4.5%
# 7901  Unemployment Rate  2007-08-03 12:30:00+00:00     4.5%   4.6%
# 7902  Unemployment Rate  2007-09-07 12:30:00+00:00     4.6%   4.6%
# 7903  Unemployment Rate  2007-10-05 12:30:00+00:00     4.7%   4.7%
# 7904  Unemployment Rate  2007-11-02 12:30:00+00:00     4.7%   4.7%
#
#       prediction_error  prediction_mean  prediction_std  prediction_zscore
# 7895             -2.22        -2.220000        1.000000           0.000000
# 7896              2.17        -0.025000        3.104199           4.390000
# 7897              4.35         1.433333        3.346376           1.409381
# 7898              0.00         1.075000        2.824730          -0.428324
# 7899              0.00         0.860000        2.493080          -0.380567
# 7900              0.00         1.304000        1.944821          -0.344955
# 7901             -2.22         0.426000        2.394970          -1.811992
# 7902              0.00        -0.444000        0.992814          -0.177873
# 7903              0.00        -0.444000        0.992814           0.447214
# 7904              0.00        -0.444000        0.992814           0.447214

# %%
df[['new', 'forecast','actual', 'prediction_error', 'prediction_mean', 'prediction_std', 'prediction_zscore']].head(10)
# Out:
#                    new forecast actual  prediction_error  prediction_mean  \
# 0  Consumer Credit m/m     5.4B  12.3B           -127.78      -127.780000
# 1  Consumer Credit m/m     7.0B   6.0B             14.29       -56.745000
# 2  Consumer Credit m/m     7.0B   6.4B              8.57       -34.973333
# 3  Consumer Credit m/m     5.5B   3.0B             45.45       -14.867500
# 4  Consumer Credit m/m     4.2B  13.5B           -221.43       -56.180000
# 5  Consumer Credit m/m     6.0B   2.6B             56.67       -19.290000
# 6  Consumer Credit m/m     6.4B  12.9B           -101.56       -42.460000
# 7  Consumer Credit m/m     5.5B  13.2B           -140.00       -72.174000
# 8  Consumer Credit m/m     8.8B   7.5B             14.77       -78.310000
# 9  Consumer Credit m/m    10.0B  12.2B            -22.00       -38.424000
#
#    prediction_std  prediction_zscore
# 0        1.000000           0.000000
# 1      100.458660         142.070000
# 2       80.423800           0.650168
# 3       76.999804           0.999994
# 4      113.931298          -2.682637
# 5      114.810240           0.990509
# 6      117.985229          -0.716574
# 7      120.599998          -0.826714
# 8      113.702506           0.720929
# 9       81.311218           0.495240

# %%
df.head(2)
# Out:
#    index actual country             datetime forecast forecast_error impact  \
# 0      0  12.3B     USD  2007-01-08 15:00:00     5.4B         better    Low
# 1     65   6.0B     USD  2007-02-07 15:00:00     7.0B          worse    Low
#
#                    new previous previous_error        ...          high_240  \
# 0  Consumer Credit m/m    -1.3B       accurate        ...             13038
# 1  Consumer Credit m/m    13.7B         better        ...             13022
#
#   low_240  close_240  volatility_240  direction_240  pips_agg_240  \
# 0   13034      13036               4             up            18
# 1   13017      13021               5             up            16
#
#   pips_candle_240  prediction_mean  prediction_std  prediction_zscore
# 0               1         -127.780         1.00000               0.00
# 1               2          -56.745       100.45866             142.07
#
# [2 rows x 87 columns]

# %%
df1 = df.groupby('new').forecast_error_ratio.mean()
df1 = df1.reset_index()

# %%
df1['new'].unique()
# Out:
# array(['ADP Non-Farm Employment Change', 'Advance GDP Price Index q/q',
#        'Advance GDP q/q', 'Average Hourly Earnings m/m',
#        'Building Permits', 'Business Inventories m/m',
#        'CB Consumer Confidence', 'CB Leading Index m/m', 'CPI m/m',
#        'Capacity Utilization Rate', 'Chicago PMI',
#        'Construction Spending m/m', 'Consumer Credit m/m', 'Core CPI m/m',
#        'Core Durable Goods Orders m/m', 'Core PCE Price Index m/m',
#        'Core PPI m/m', 'Core Retail Sales m/m', 'Crude Oil Inventories',
#        'Current Account', 'Durable Goods Orders m/m',
#        'Empire State Manufacturing Index', 'Employment Cost Index q/q',
#        'Existing Home Sales', 'Factory Orders m/m',
#        'Federal Budget Balance', 'Federal Funds Rate',
#        'Final GDP Price Index q/q', 'Final GDP q/q',
#        'Final Manufacturing PMI', 'Final Services PMI',
#        'Final Wholesale Inventories m/m', 'Flash Manufacturing PMI',
#        'Flash Services PMI', 'Goods Trade Balance', 'HPI m/m',
#        'Housing Starts', 'IBD/TIPP Economic Optimism',
#        'ISM Manufacturing PMI', 'ISM Manufacturing Prices',
#        'ISM Non-Manufacturing PMI', 'Import Prices m/m',
#        'Industrial Production m/m', 'JOLTS Job Openings',
#        'NAHB Housing Market Index', 'NFIB Small Business Index',
#        'Natural Gas Storage', 'New Home Sales',
#        'Non-Farm Employment Change', 'PPI m/m', 'Pending Home Sales m/m',
#        'Personal Income m/m', 'Personal Spending m/m',
#        'Philly Fed Manufacturing Index', 'Prelim GDP Price Index q/q',
#        'Prelim GDP q/q', 'Prelim Nonfarm Productivity q/q',
#        'Prelim Unit Labor Costs q/q', 'Prelim UoM Consumer Sentiment',
#        'Prelim Wholesale Inventories m/m', 'Retail Sales m/m',
#        'Revised Nonfarm Productivity q/q', 'Revised Unit Labor Costs q/q',
#        'Revised UoM Consumer Sentiment', 'Richmond Manufacturing Index',
#        'S&P/CS Composite-20 HPI y/y', 'TIC Long-Term Purchases',
#        'Total Vehicle Sales', 'Trade Balance', 'Unemployment Claims',
#        'Unemployment Rate'], dtype=object)

# %%
df[df['new']=='ADP Non-Farm Employment Change'].head(4)
# Out:
#     actual country             datetime forecast forecast_error  impact  \
# 39    152K     USD  2007-01-31 08:15:00     135K         better  Medium
# 122    57K     USD  2007-03-07 08:15:00     100K          worse  Medium
# 182   106K     USD  2007-04-04 08:15:00     125K          worse    High
# 243    64K     USD  2007-05-02 08:15:00     107K          worse    High
#
#                                 new previous previous_error  week  \
# 39   ADP Non-Farm Employment Change     147K         better     5
# 122  ADP Non-Farm Employment Change     121K          worse    10
# 182  ADP Non-Farm Employment Change      65K         better    14
# 243  ADP Non-Farm Employment Change      98K          worse    18
#
#          ...       direction_60  pips_diff_60  close_90  volatility_90  \
# 39       ...                 up          11.0     12967             16
# 122      ...                 up           5.0     13133              4
# 182      ...                 up           1.0     13356             11
# 243      ...                 up          14.0     13587              2
#
#      direction_90 pips_diff_90  close_120  volatility_120  direction_120  \
# 39             up         14.0      12973               6             up
# 122          down          1.0      13142               5             up
# 182            up          7.0      13360               5             up
# 243          down          7.0      13585               6           down
#
#      pips_diff_120
# 39            20.0
# 122           10.0
# 182           11.0
# 243            5.0
#
# [4 rows x 48 columns]

# %%
# Out:
# 39      NaN
# 122     NaN
# 182    152K
# 243     57K
# Name: actual, dtype: object

# %%
df_temp = df[df['datetime_gmt'] == '2018-06-01 12:30:00+00:00']
df_temp.head()
# Out:
#       index actual country             datetime forecast forecast_error  \
# 7890    366   223K     USD  2018-06-01 08:30:00     189K         better
# 8031    367   3.8%     USD  2018-06-01 08:30:00     3.9%         better
# 8172    365   0.3%     USD  2018-06-01 08:30:00     0.2%         better
#
#      impact                          new previous previous_error  \
# 7890   High   Non-Farm Employment Change     159K       accurate
# 8031   High            Unemployment Rate     3.9%       accurate
# 8172   High  Average Hourly Earnings m/m     0.1%       accurate
#
#             ...          high_240 low_240  close_240  volatility_240  \
# 7890        ...             11674   11669      11672               5
# 8031        ...             11674   11669      11672               5
# 8172        ...             11674   11669      11672               5
#
#       direction_240  pips_agg_240 pips_candle_240  prediction_mean  \
# 7890           down             0               1    -4.456000e+00
# 8031           down             0               1     1.200000e-02
# 8172           down             0               1     2.842171e-15
#
#       prediction_std  prediction_zscore
# 7890       36.540660          -0.579069
# 8031        2.515098           1.462960
# 8172       50.000000          -1.434274
#
# [3 rows x 87 columns]

# %%
df_temp[['new', 'datetime_gmt','pips_agg_30','direction_30','volatility_30','direction_60','pips_agg_60','forecast','actual', 'prediction_error', 'prediction_mean', 'prediction_std', 'prediction_zscore']]
# Out:
#                               new               datetime_gmt  pips_agg_30  \
# 7890   Non-Farm Employment Change  2018-06-01 12:30:00+00:00           14
# 8031            Unemployment Rate  2018-06-01 12:30:00+00:00           14
# 8172  Average Hourly Earnings m/m  2018-06-01 12:30:00+00:00           14
#
#      direction_30  volatility_30 direction_60  pips_agg_60 forecast actual  \
# 7890         down             16           up           10     189K   223K
# 8031         down             16           up           10     3.9%   3.8%
# 8172         down             16           up           10     0.2%   0.3%
#
#       prediction_error  prediction_mean  prediction_std  prediction_zscore
# 7890            -17.99    -4.456000e+00       36.540660          -0.579069
# 8031              2.56     1.200000e-02        2.515098           1.462960
# 8172            -50.00     2.842171e-15       50.000000          -1.434274

# %%
df_temp = df[df['new'] == 'Unemployment Claims']
df_temp[['new', 'datetime_gmt','pips_agg_30','forecast','actual', 'prediction_error', 'prediction_mean', 'prediction_std', 'prediction_zscore']].tail(5)
# Out:
#                       new               datetime_gmt  pips_agg_30 forecast  \
# 1795  Unemployment Claims  2018-09-27 12:30:00+00:00           17     208K
# 1796  Unemployment Claims  2018-10-04 12:30:00+00:00           11     214K
# 1797  Unemployment Claims  2018-10-11 12:30:00+00:00            4     207K
# 1798  Unemployment Claims  2018-10-18 12:30:00+00:00            6     211K
# 1799  Unemployment Claims  2018-10-25 12:30:00+00:00           15     214K
#
#      actual  prediction_error  prediction_mean  prediction_std  \
# 1795   214K             -2.88            1.976        3.240205
# 1796   207K              3.27            2.536        3.155714
# 1797   214K             -3.38            0.832        3.658356
# 1798   210K              0.47            0.354        3.478869
# 1799   215K             -0.47           -0.598        2.695621
#
#       prediction_zscore
# 1795          -3.257684
# 1796           0.399357
# 1797          -1.874695
# 1798          -0.098952
# 1799          -0.236859

# %%
# %matplotlib
df_temp.pips_agg_30.hist()
# Out:
# Using matplotlib backend: MacOSX
