# %%
import pandas as pd

# %%
df = pd.read_csv('macroeconomic_news_news_USD_pair_EURUSD_2007_2018.csv')

# %%
df.head(2)
# Out:
#   actual country             datetime forecast forecast_error impact  \
# 0  12.3B     USD  2007-01-08 15:00:00     5.4B         better    Low
# 1   6.0B     USD  2007-02-07 15:00:00     7.0B          worse    Low
#
#                    new previous previous_error  week  \
# 0  Consumer Credit m/m    -1.3B       accurate     2
# 1  Consumer Credit m/m    13.7B         better     6
#
#              ...            pips_candle_240_before  previous_value  \
# 0            ...                               1.0           -1.3B
# 1            ...                               0.0           12.3B
#
#    previous_error_ratio  total_error_ratio  forecast_error_ratio_mean  \
# 0                  0.00             127.78                    127.780
# 1                 11.38              -2.91                     56.745
#
#    forecast_error_ratio_std  forecast_error_ratio_zscore  \
# 0                   1.00000                     0.000000
# ...

# %%
df_temp = df[df['datetime'] == '2018-10-25 08:30:00']

# %%
df_temp[['new','datetime', 'datetime_gmt','close_released', 'close_5_before', 'close_10_before', 'close_15_before', 'close_30_before', 'close_45_before', 'close_60_before', 
         'close_90_before', 'close_120_before', 'close_150_before','close_180_before']]
# Out:
#                                    new             datetime  \
# 1799               Unemployment Claims  2018-10-25 08:30:00
# 5539     Core Durable Goods Orders m/m  2018-10-25 08:30:00
# 5681          Durable Goods Orders m/m  2018-10-25 08:30:00
# 9639               Goods Trade Balance  2018-10-25 08:30:00
# 9666  Prelim Wholesale Inventories m/m  2018-10-25 08:30:00
#
#                    datetime_gmt  close_released  close_5_before  \
# 1799  2018-10-25 12:30:00+00:00           11415           11415
# 5539  2018-10-25 12:30:00+00:00           11415           11415
# 5681  2018-10-25 12:30:00+00:00           11415           11415
# 9639  2018-10-25 12:30:00+00:00           11415           11415
# 9666  2018-10-25 12:30:00+00:00           11415           11415
#
#       close_10_before  close_15_before  close_30_before  close_45_before  \
# 1799            11416            11415          11415.0          11413.0
# ...

# %%
df_temp[['new','datetime', 'datetime_gmt','close_released', 'close_5_after', 'close_10_after', 'close_15_after', 'close_30_after', 'close_45_after', 'close_60_after', 
         'close_90_after', 'close_120_after', 'close_150_after','close_180_after']]
# Out:
#                                    new             datetime  \
# 1799               Unemployment Claims  2018-10-25 08:30:00
# 5539     Core Durable Goods Orders m/m  2018-10-25 08:30:00
# 5681          Durable Goods Orders m/m  2018-10-25 08:30:00
# 9639               Goods Trade Balance  2018-10-25 08:30:00
# 9666  Prelim Wholesale Inventories m/m  2018-10-25 08:30:00
#
#                    datetime_gmt  close_released  close_5_after  \
# 1799  2018-10-25 12:30:00+00:00           11415          11418
# 5539  2018-10-25 12:30:00+00:00           11415          11418
# 5681  2018-10-25 12:30:00+00:00           11415          11418
# 9639  2018-10-25 12:30:00+00:00           11415          11418
# 9666  2018-10-25 12:30:00+00:00           11415          11418
#
#       close_10_after  close_15_after  close_30_after  close_45_after  \
# 1799           11422           11411         11427.0         11414.0
# 5539           11422           11411         11427.0         11414.0
# ...
