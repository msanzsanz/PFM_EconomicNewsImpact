# %% [markdown]
# # GETTING FAMILIAR WITH THE DATA
# ----

# %% [markdown]
# ## Forex Factory <a name="forex"></a>
#
#
# Data from https://www.forexfactory.com/ was gotten using our own scrapper. Thus, we need to do some sanity checks to ensure that the downloaded data corresponds to the expected one.
#
# As we have data from several years, the best approach for data curation is to create a script.
# Before that, we need to explore the data for getting familiarity with our dataset. That´s exactly the goal of this notebook.
#
#
# -----------

# %%
import pandas as pd
import numpy as np

# %%
data_directory_news = '../data/raw/'

# %% [markdown]
# ### Initial exploratory analysis, just for 2017, to get familiar to the data

# %%
ff_2017 = pd.read_csv(data_directory_news + 'forexfactory_2017.csv')

# %%
ff_2017.head()
# Out:
#    Unnamed: 0 actual country             datetime forecast forecast_error  \
# 0           0    NaN     NZD  2017-12-31 00:00:00      NaN            NaN
# 1           1    NaN     AUD  2017-12-31 00:00:00      NaN            NaN
# 2           2    NaN     JPY  2017-12-31 00:00:00      NaN            NaN
# 3           3    NaN     CNY  2017-12-31 00:00:00      NaN            NaN
# 4           4    NaN     NZD  2017-12-24 00:00:00      NaN            NaN
#
#          impact           new previous previous_error  week
# 0  Non-Economic  Bank Holiday      NaN            NaN    52
# 1  Non-Economic  Bank Holiday      NaN            NaN    52
# 2  Non-Economic  Bank Holiday      NaN            NaN    52
# 3  Non-Economic  Bank Holiday      NaN            NaN    52
# 4  Non-Economic  Bank Holiday      NaN            NaN    52

# %%
ff_2017 = ff_2017.drop(columns = ['Unnamed: 0'])
ff_2017.describe()
# Out:
#               week
# count  4566.000000
# mean     26.382611
# std      15.019860
# min       1.000000
# 25%      13.000000
# 50%      26.000000
# 75%      40.000000
# max      52.000000

# %%
ff_2017.dtypes
# Out:
# actual            object
# country           object
# datetime          object
# forecast          object
# forecast_error    object
# impact            object
# new               object
# previous          object
# previous_error    object
# week               int64
# dtype: object

# %% [markdown]
# Please note that **"forecast_error"** is a variable that I´ve created when scrapping the website, set to NaN whenever there was no error between the published forecast and the actual value.<br/>
# Equivalently, **"previous_error"** was also created by me, set to NaN whenever there was no goverment correction on the published value for the previous release event.
#
# Let´s replace those NaN by a categorical value = 'accurate'

# %%
ff_2017['forecast_error'] = ff_2017['forecast_error'].replace(np.nan, 'accurate', regex=True)
ff_2017['previous_error'] = ff_2017['previous_error'].replace(np.nan, 'accurate', regex=True)

# %% [markdown]
# Our preliminary analysis is going to be focused on **EUR-USD only**, analysing the impact of news published by the American government, so we filter the dataframe to only get **macroeconomic news from USA** (macroeconomic news = those which have a forecast)

# %%
ff_2017_USA = ff_2017[ff_2017['country'] == 'USD'] 
ff_2017_USA = ff_2017_USA[ff_2017_USA['forecast'].notnull()]
ff_2017_USA.head()
# Out:
#    actual country             datetime forecast forecast_error  impact  \
# 27   6.4%     USD  2017-12-26 09:00:00     6.3%       accurate     Low
# 28     20     USD  2017-12-26 09:59:00       22          worse     Low
# 32  122.1     USD  2017-12-27 10:00:00    128.2          worse    High
# 33   0.2%     USD  2017-12-27 10:00:00    -0.4%         better  Medium
# 41   245K     USD  2017-12-28 08:30:00     240K          worse    High
#
#                              new previous previous_error  week
# 27   S&P/CS Composite-20 HPI y/y     6.2%       accurate    52
# 28  Richmond Manufacturing Index       30       accurate    52
# 32        CB Consumer Confidence    128.6          worse    52
# 33        Pending Home Sales m/m     3.5%       accurate    52
# 41           Unemployment Claims     245K       accurate    52

# %% [markdown]
# How many macro-economical news are published each year?

# %%
len(ff_2017_USA)
# Out:
# 872

# %% [markdown]
# How many released grouped by 'impact' rate?

# %%
ff_2017_USA_high = ff_2017_USA[ff_2017_USA['impact'] == 'High']
ff_2017_USA_medium = ff_2017_USA[ff_2017_USA['impact'] == 'Medium']
ff_2017_USA_low = ff_2017_USA[ff_2017_USA['impact'] == 'Low']

print('High: ' + str(len(ff_2017_USA_high)) + ' - Medium: ' + str(len(ff_2017_USA_medium)) + ' - Low: ' + str(len(ff_2017_USA_low)))
# Out:
# High: 296 - Medium: 243 - Low: 333

# %%
len(ff_2017_USA_high) *100/len(ff_2017_USA)
# Out:
# 33.944954128440365

# %%
len(ff_2017_USA_medium) *100/len(ff_2017_USA)
# Out:
# 27.86697247706422

# %%
len(ff_2017_USA_low) *100/len(ff_2017_USA)
# Out:
# 38.18807339449541

# %% [markdown]
# Our favourite news for this analysis are those with higher expected impact on the market. Let´s see how many of them we have

# %%
print('number of news, high: ' + 
      str(len(ff_2017_USA_high.groupby('new').impact.count())) +
      ' - med: ' +
        str(len(ff_2017_USA_medium.groupby('new').impact.count())) +
      ' - low: ' + 
        str(len(ff_2017_USA_low.groupby('new').impact.count())))
# Out:
# number of news, high: 22 - med: 27 - low: 29

# %%
ff_2017_USA_high.groupby('new').impact.count()
# Out:
# new
# ADP Non-Farm Employment Change    12
# Advance GDP q/q                    4
# Average Hourly Earnings m/m       12
# Building Permits                  12
# CB Consumer Confidence            12
# CPI m/m                           12
# Core CPI m/m                      12
# Core Durable Goods Orders m/m     12
# Core Retail Sales m/m             12
# Crude Oil Inventories             52
# Federal Funds Rate                 6
# Final GDP q/q                      4
# ISM Manufacturing PMI             12
# ISM Non-Manufacturing PMI         12
# Non-Farm Employment Change        12
# PPI m/m                           12
# Philly Fed Manufacturing Index     4
# Prelim GDP q/q                     4
# Prelim UoM Consumer Sentiment      4
# Retail Sales m/m                  12
# Unemployment Claims               50
# Unemployment Rate                 12
# Name: impact, dtype: int64

# %% [markdown]
# Hmmm, not that many... :-(

# %% [markdown]
# Interesting to see that some news have High impact most of the times, but Medium impact some other times, like 'Unemployment Claims'

# %%
ff_2017_USA[ff_2017_USA['new'] == 'Unemployment Claims']
# Out:
#      actual country             datetime forecast forecast_error  impact  \
# 41     245K     USD  2017-12-28 08:30:00     240K          worse    High
# 109    245K     USD  2017-12-21 08:30:00     232K          worse  Medium
# 219    225K     USD  2017-12-14 08:30:00     237K         better  Medium
# 303    236K     USD  2017-12-07 08:30:00     239K       accurate    High
# 413    238K     USD  2017-11-30 08:30:00     241K       accurate    High
# 477    239K     USD  2017-11-22 08:30:00     241K       accurate    High
# 586    249K     USD  2017-11-16 08:30:00     235K          worse    High
# 684    239K     USD  2017-11-09 08:30:00     232K          worse    High
# 799    229K     USD  2017-11-02 07:30:00     235K         better    High
# 870    233K     USD  2017-10-26 07:30:00     235K       accurate    High
# 954    222K     USD  2017-10-19 07:30:00     240K         better    High
# 1022   243K     USD  2017-10-12 07:30:00     251K         better    High
# 1128   260K     USD  2017-10-05 07:30:00     266K         better    High
# 1204   272K     USD  2017-09-28 07:30:00     269K       accurate    High
# 1308   259K     USD  2017-09-21 07:30:00     302K         better    High
# 1396   284K     USD  2017-09-14 07:30:00     303K         better    High
# 1478   298K     USD  2017-09-07 07:30:00     245K          worse    High
# 1572   236K     USD  2017-08-31 07:30:00     237K       accurate    High
# 1645   234K     USD  2017-08-24 07:30:00     237K       accurate    High
# 1721   232K     USD  2017-08-17 07:30:00     240K         better    High
# 1800   244K     USD  2017-08-10 07:30:00     240K       accurate    High
# 1908   240K     USD  2017-08-03 07:30:00     242K       accurate    High
# 1974   244K     USD  2017-07-27 07:30:00     240K       accurate    High
# 2052   233K     USD  2017-07-20 07:30:00     245K         better    High
# 2127   247K     USD  2017-07-13 07:30:00     245K       accurate    High
# 2218   248K     USD  2017-07-06 07:30:00     243K          worse    High
# 2302   244K     USD  2017-06-29 07:30:00     241K       accurate    High
# 2382   241K     USD  2017-06-22 07:30:00     241K       accurate    High
# 2483   237K     USD  2017-06-15 07:30:00     241K       accurate    High
# 2571   245K     USD  2017-06-08 07:30:00     241K       accurate    High
# 2673   248K     USD  2017-06-01 07:30:00     239K          worse    High
# 2757   234K     USD  2017-05-25 07:30:00     238K       accurate    High
# 2835   232K     USD  2017-05-18 07:30:00     240K         better    High
# 2926   236K     USD  2017-05-11 07:30:00     245K         better    High
# 3026   238K     USD  2017-05-04 07:30:00     246K         better    High
# 3097   257K     USD  2017-04-27 07:30:00     241K          worse    High
# 3190   244K     USD  2017-04-20 07:30:00     241K       accurate    High
# 3286   234K     USD  2017-04-13 07:30:00     242K         better    High
# 3388   234K     USD  2017-04-06 07:30:00     251K         better    High
# 3452   258K     USD  2017-03-30 07:30:00     244K          worse    High
# 3552   261K     USD  2017-03-23 07:30:00     240K          worse    High
# 3653   241K     USD  2017-03-16 07:30:00     245K       accurate    High
# 3735   243K     USD  2017-03-09 08:30:00     239K       accurate    High
# 3855   223K     USD  2017-03-02 08:30:00     243K         better    High
# 3942   244K     USD  2017-02-23 08:30:00     242K       accurate    High
# 4024   239K     USD  2017-02-16 08:30:00     243K       accurate    High
# 4095   234K     USD  2017-02-09 08:30:00     249K         better    High
# 4221   246K     USD  2017-02-02 08:30:00     251K         better    High
# 4291   259K     USD  2017-01-26 08:30:00     247K          worse    High
# 4382   234K     USD  2017-01-19 08:30:00     252K         better    High
# 4457   247K     USD  2017-01-12 08:30:00     266K         better    High
# 4542   235K     USD  2017-01-05 08:30:00     262K         better    High
#
#                       new previous previous_error  week
# 41    Unemployment Claims     245K       accurate    52
# 109   Unemployment Claims     225K       accurate    51
# 219   Unemployment Claims     236K       accurate    50
# 303   Unemployment Claims     238K       accurate    49
# 413   Unemployment Claims     240K       accurate    48
# 477   Unemployment Claims     252K       accurate    47
# 586   Unemployment Claims     239K       accurate    46
# 684   Unemployment Claims     229K       accurate    45
# 799   Unemployment Claims     234K       accurate    44
# 870   Unemployment Claims     223K       accurate    43
# 954   Unemployment Claims     244K       accurate    42
# 1022  Unemployment Claims     258K       accurate    41
# 1128  Unemployment Claims     272K       accurate    40
# 1204  Unemployment Claims     260K       accurate    39
# 1308  Unemployment Claims     282K       accurate    38
# 1396  Unemployment Claims     298K       accurate    37
# 1478  Unemployment Claims     236K       accurate    36
# 1572  Unemployment Claims     235K       accurate    35
# 1645  Unemployment Claims     232K       accurate    34
# 1721  Unemployment Claims     244K       accurate    33
# 1800  Unemployment Claims     241K       accurate    32
# 1908  Unemployment Claims     245K       accurate    31
# 1974  Unemployment Claims     234K       accurate    30
# 2052  Unemployment Claims     248K       accurate    29
# 2127  Unemployment Claims     250K       accurate    28
# 2218  Unemployment Claims     244K       accurate    27
# 2302  Unemployment Claims     242K       accurate    26
# 2382  Unemployment Claims     238K       accurate    25
# 2483  Unemployment Claims     245K       accurate    24
# 2571  Unemployment Claims     255K          worse    23
# 2673  Unemployment Claims     235K       accurate    22
# 2757  Unemployment Claims     233K       accurate    21
# 2835  Unemployment Claims     236K       accurate    20
# 2926  Unemployment Claims     238K       accurate    19
# 3026  Unemployment Claims     257K       accurate    18
# 3097  Unemployment Claims     243K       accurate    17
# 3190  Unemployment Claims     234K       accurate    16
# 3286  Unemployment Claims     235K       accurate    15
# 3388  Unemployment Claims     259K       accurate    14
# 3452  Unemployment Claims     261K       accurate    13
# 3552  Unemployment Claims     246K          worse    12
# 3653  Unemployment Claims     243K       accurate    11
# 3735  Unemployment Claims     223K       accurate    10
# 3855  Unemployment Claims     242K       accurate     9
# 3942  Unemployment Claims     238K       accurate     8
# 4024  Unemployment Claims     234K       accurate     7
# 4095  Unemployment Claims     246K       accurate     6
# 4221  Unemployment Claims     260K       accurate     5
# 4291  Unemployment Claims     237K       accurate     4
# 4382  Unemployment Claims     249K       accurate     3
# 4457  Unemployment Claims     237K       accurate     2
# 4542  Unemployment Claims     263K       accurate     1

# %% [markdown]
# We need to know which meassure units are used per each macroeconomic new, so that we can compute the error rate between forecast and reality.

# %%
list(set(ff_2017_USA.groupby('new').actual.first()))
# Out:
# ['77.1%',
#  '733K',
#  '67.6',
#  '0.2%',
#  '0.6%',
#  '17.5M',
#  '190K',
#  '23.2B',
#  '74',
#  '245K',
#  '65.5',
#  '2.2%',
#  '58.2',
#  '20',
#  '4.1%',
#  '-69.7B',
#  '228K',
#  '0.1%',
#  '18.0',
#  '-138.5B',
#  '52.4',
#  '51.9',
#  '95.9',
#  '6.4%',
#  '0.3%',
#  '3.3%',
#  '96.8',
#  '5.81M',
#  '0.5%',
#  '53.9',
#  '0.8%',
#  '-0.5%',
#  '3.2%',
#  '1.4%',
#  '1.30M',
#  '122.1',
#  '3.0%',
#  '54.5',
#  '55.0',
#  '107.5',
#  '2.1%',
#  '1.0%',
#  '57.4',
#  '-101B',
#  '1.3%',
#  '0.7%',
#  '6.00M',
#  '<1.50%',
#  '26.2',
#  '20.5B',
#  '0.4%',
#  '-112B',
#  '-0.1%',
#  '-0.2%',
#  '-48.7B',
#  '-4.6M']

# %% [markdown]
# Let´s see how many times forex factory publishes a wrong forecast

# %%
ff_2017_USA.groupby('forecast_error').impact.count()
# Out:
# forecast_error
# accurate    301
# better      288
# worse       283
# Name: impact, dtype: int64

# %% [markdown]
# Cool, forexfactory.com publishes non-accurate forecasts around 2/3 of the times !

# %% [markdown]
# Are there news published on the same day?

# %%
ff_2017_USA.groupby('datetime').new.count().sort_values(ascending=False)
# Out:
# datetime
# 2017-09-28 07:30:00    5
# 2017-03-15 07:30:00    5
# 2017-04-27 07:30:00    5
# 2017-07-27 07:30:00    5
# 2017-12-22 08:30:00    5
# 2017-11-15 08:30:00    5
# 2017-02-15 08:30:00    5
# 2017-05-12 07:30:00    4
# 2017-03-16 07:30:00    4
# 2017-11-30 08:30:00    4
# 2017-06-14 07:30:00    4
# 2017-12-14 08:30:00    4
# 2017-09-19 07:30:00    4
# 2017-01-19 08:30:00    4
# 2017-08-31 07:30:00    4
# 2017-01-27 08:30:00    4
# 2017-04-14 07:30:00    4
# 2017-11-03 07:30:00    4
# 2017-01-13 08:30:00    4
# 2017-10-13 07:30:00    4
# 2017-07-14 07:30:00    4
# 2017-05-04 07:30:00    4
# 2017-09-01 09:00:00    4
# 2017-06-15 07:30:00    4
# 2017-12-21 08:30:00    4
# 2017-06-02 07:30:00    4
# 2017-02-28 08:30:00    4
# 2017-05-26 07:30:00    4
# 2017-08-04 07:30:00    4
# 2017-02-16 08:30:00    4
#                       ..
# 2017-08-22 08:00:00    1
# 2017-08-17 09:30:00    1
# 2017-07-20 09:30:00    1
# 2017-08-17 09:00:00    1
# 2017-07-24 09:00:00    1
# 2017-07-25 08:59:00    1
# 2017-07-25 09:00:00    1
# 2017-07-26 09:00:00    1
# 2017-07-26 09:30:00    1
# 2017-07-26 13:00:00    1
# 2017-07-27 09:30:00    1
# 2017-07-28 09:00:00    1
# 2017-07-31 08:45:00    1
# 2017-07-31 09:00:00    1
# 2017-08-01 00:00:00    1
# 2017-08-01 08:45:00    1
# 2017-08-02 07:15:00    1
# 2017-08-02 09:30:00    1
# 2017-08-03 07:30:00    1
# 2017-08-03 08:45:00    1
# 2017-08-03 09:30:00    1
# 2017-08-07 14:00:00    1
# 2017-08-08 05:00:00    1
# 2017-08-09 09:00:00    1
# 2017-08-09 09:30:00    1
# 2017-08-10 09:30:00    1
# 2017-08-10 13:00:00    1
# 2017-08-15 15:00:00    1
# 2017-08-16 09:30:00    1
# 2017-01-03 09:45:00    1
# Name: new, Length: 574, dtype: int64

# %% [markdown]
# Ok, there are... Not great news ... :-(
#
# Let´s see one of them as an example

# %%
ff_2017_USA[ff_2017_USA['datetime'] == '2017-09-28 07:30:00']
# Out:
#       actual country             datetime forecast forecast_error impact  \
# 1203    3.1%     USD  2017-09-28 07:30:00     3.0%         better   High
# 1204    272K     USD  2017-09-28 07:30:00     269K       accurate   High
# 1205    1.0%     USD  2017-09-28 07:30:00     1.0%       accurate    Low
# 1206  -62.9B     USD  2017-09-28 07:30:00   -65.0B         better    Low
# 1207    1.0%     USD  2017-09-28 07:30:00     0.4%          worse    Low
#
#                                    new previous previous_error  week
# 1203                     Final GDP q/q     3.0%       accurate    39
# 1204               Unemployment Claims     260K       accurate    39
# 1205         Final GDP Price Index q/q     1.0%       accurate    39
# 1206               Goods Trade Balance   -63.9B         better    39
# 1207  Prelim Wholesale Inventories m/m     0.6%          worse    39

# %% [markdown]
#  Which % of news are published at the same time?

# %%
df_temp = ff_2017_USA.groupby('datetime').new.count().reset_index()
df_temp.columns = ['datetime', 'news']
df_temp.head(2)
# Out:
#               datetime  news
# 0  2017-01-03 09:45:00     1
# 1  2017-01-03 10:00:00     3

# %%
len(df_temp[df_temp['news'] > 1]) * 100 / len(df_temp)
# Out:
# 31.010452961672474

# %% [markdown]
# Ok, 31%, not a negliglable number...

# %% [markdown]
# The news classified as 'High' impact, which % of times they are released in bundles?

# %%
df_temp = ff_2017_USA_high.groupby('datetime').new.count().reset_index()
df_temp.columns = ['datetime', 'news']
len(df_temp[df_temp['news'] > 1]) * 100 / len(df_temp)
# Out:
# 20.642201834862384

# %% [markdown]
# ---
#
# ## Next steps on Forex Factory <a name="next_forex"></a>
#
# ### Sanity checks:
#
#  - Check that the raw data has no missing weeks.
#
# ### Data selection:
#
#  - Filter out non macro-economic news.
#  - Filter out non USA news.
#
# ### Feature Engineer:
#
#  - Compute % of error between the forecast and the actual values, taking into account the different units handled (int, float, %, Millions = 'M', Thousands = 'K').
#  - Compute goverment corrections on official values published on the previous release.
#  - Set all timestamps to match the trading pair values got from Dukascopy, i.e. GMT with DTS. Otherwise we won´t compare apples with apples !
#  - Split current date and time fields to capture year, month, day of week, hour, time.
#  - Replace NaN in "forecast_error" and "previous_error" fields by "accurate".
